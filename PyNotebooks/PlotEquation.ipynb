# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets as ds
import tensorflow as tf
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
u = np.arange(-2.0, 2.0, 0.05)
xx, yy = np.meshgrid(u, u)
xx.shape, yy.shape
# Out:
# ((80, 80), (80, 80))

# %%
def func1(x, y):
    z = x**2 + y**2 - 1
    #p = np.where((z < 1e-6) & (z > -1e-6), 1, 0)
    p = np.where((z > 0.5), 1, 0)
    return p, z

pp, zz = func1(xx, yy)
#z = zz.reshape(xx.shape)
#zz.shape
np.where((z < 1e-3) & (z > -1e-3))
# Out:
# (array([18, 18, 20, 20, 24, 24, 26, 26, 30, 30, 32, 32]),
#  array([24, 26, 20, 30, 18, 32, 18, 32, 20, 30, 24, 26]))

# %%
#plt.contour(xx, yy, Z, alpha=0.3)

fig = plt.figure()

ax = fig.add_subplot('121')
ax.contour(xx,yy,zz, levels=[0.5], cmap=plt.cm.Paired)


ax = fig.add_subplot('122', projection='3d')
x1 = xx.flatten()
y1 = yy.flatten()
z1 = zz.flatten()
ax.scatter(x1, y1, pp)



plt.show()

# %%
#dt = pd.DataFrame([xx, yy, Z])
#xx.flatten().shape, yy.flatten().shape, Z.flatten().shape
dt = np.column_stack([xx.flatten().T, yy.flatten().T, Z.flatten().T])
dx = np.where(dt[:,2] == 0)
dt[dx]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-1cff6007ab88> in <module>()
#       1 #dt = pd.DataFrame([xx, yy, Z])
#       2 #xx.flatten().shape, yy.flatten().shape, Z.flatten().shape
# ----> 3 dt = np.column_stack([xx.flatten().T, yy.flatten().T, Z.flatten().T])
#       4 dx = np.where(dt[:,2] == 0)
#       5 dt[dx]
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/shape_base.py in column_stack(tup)
#     367             arr = array(arr, copy=False, subok=True, ndmin=2).T
#     368         arrays.append(arr)
# --> 369     return _nx.concatenate(arrays, 1)
#     370
#     371 def dstack(tup):
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
a = np.arange(-1, 1, 0.1)
a
# Out:
# array([-1.00000000e+00, -9.00000000e-01, -8.00000000e-01, -7.00000000e-01,
#        -6.00000000e-01, -5.00000000e-01, -4.00000000e-01, -3.00000000e-01,
#        -2.00000000e-01, -1.00000000e-01, -2.22044605e-16,  1.00000000e-01,
#         2.00000000e-01,  3.00000000e-01,  4.00000000e-01,  5.00000000e-01,
#         6.00000000e-01,  7.00000000e-01,  8.00000000e-01,  9.00000000e-01])

# %%
b = (a < 0.01) & (a > -0.01)
b
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False])
